# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('sales.csv')

# %%
df
# Out:
#         STORE_KEY  STORE_NUMBER   OPEN_DATE  BUSINESS_DATE_KEY BUSINESS_DATE  \
# 0            1402           580   10/5/2011           20230203      2/3/2023
# 1            2104          1323  11/21/2017           20221008     10/8/2022
# 2            1753           969    2/6/2006           20230330     3/30/2023
# 3            2443          1664    2/3/2020           20230307      3/7/2023
# 4            1859          1078   3/11/2016           20221105     11/5/2022
# ...           ...           ...         ...                ...           ...
# 632192       1908          1127  11/30/2015           20231127    11/27/2023
# 632193       2268          1489   6/30/2018           20231014    10/14/2023
# 632194       1929          1148   4/27/2016           20231111    11/11/2023
# 632195       2411          1632   5/19/2019           20221109     11/9/2022
# 632196       2129          1349    6/1/2017           20220801      8/1/2022
#
# ...

# %%
dfn=df.sort_values(['STORE_KEY','BUSINESS_DATE_KEY'])
dfn
# Out:
#         STORE_KEY  STORE_NUMBER   OPEN_DATE  BUSINESS_DATE_KEY BUSINESS_DATE  \
# 129859          9          1699   10/7/2019           20191007     10/7/2019
# 129747          9          1699   10/7/2019           20191008     10/8/2019
# 426648          9          1699   10/7/2019           20191009     10/9/2019
# 504057          9          1699   10/7/2019           20191010    10/10/2019
# 147595          9          1699   10/7/2019           20191011    10/11/2019
# ...           ...           ...         ...                ...           ...
# 150577     694934          2622  12/16/2023           20231227    12/27/2023
# 156384     694934          2622  12/16/2023           20231228    12/28/2023
# 520239     694934          2622  12/16/2023           20231229    12/29/2023
# 48983      694934          2622  12/16/2023           20231230    12/30/2023
# 456205     694934          2622  12/16/2023           20231231    12/31/2023
#
# ...

# %%
hier_index = pd.MultiIndex.from_tuples(list(zip(dfn['STORE_KEY'].values,dfn['STORE_NUMBER'].values,dfn['OPEN_DATE'].values)))
dfn.index=hier_index
dfn.index.names=['STORE_KEY_INDEX','STORE_NUMBER_INDEX','OPEN_DATE']
dfn
# Out:
#                                                STORE_KEY  STORE_NUMBER  \
# STORE_KEY_INDEX STORE_NUMBER_INDEX OPEN_DATE
# 9               1699               10/7/2019           9          1699
#                                    10/7/2019           9          1699
#                                    10/7/2019           9          1699
#                                    10/7/2019           9          1699
#                                    10/7/2019           9          1699
# ...                                                  ...           ...
# 694934          2622               12/16/2023     694934          2622
#                                    12/16/2023     694934          2622
#                                    12/16/2023     694934          2622
#                                    12/16/2023     694934          2622
#                                    12/16/2023     694934          2622
#
# ...

# %%
hm = df.isnull()

# %%
sns.heatmap(hm)
# Out:
# <Axes: >

# %%
dfn['STORE_KEY'].nunique(),dfn['OPEN_DATE'].nunique()
# Out:
# (477, 453)

# %%
dfn.sort_values(['STORE_KEY_INDEX','NET_SALES_FINAL_USD_AMOUNT'])
# Out:
#                                                STORE_KEY  STORE_NUMBER  \
# STORE_KEY_INDEX STORE_NUMBER_INDEX OPEN_DATE
# 9               1699               10/7/2019           9          1699
#                                    10/7/2019           9          1699
#                                    10/7/2019           9          1699
#                                    10/7/2019           9          1699
#                                    10/7/2019           9          1699
# ...                                                  ...           ...
# 694934          2622               12/16/2023     694934          2622
#                                    12/16/2023     694934          2622
#                                    12/16/2023     694934          2622
#                                    12/16/2023     694934          2622
#                                    12/16/2023     694934          2622
#
# ...

# %%
store = pd.read_csv('store.csv')

# %%
stores=store.copy()
store
# Out:
#       STORE_KEY  STORE_NUMBER   ROW_EFFECTIVE_TIMESTAMP  \
# 0       1319795          2821  2024-05-21T02:07:19.714Z
# 1       1319796          2822  2024-05-21T02:07:19.714Z
# 2       1318778          2819  2024-05-21T02:07:19.714Z
# 3       1318779          2820  2024-05-21T02:07:19.714Z
# 4       1318780          2816  2024-05-21T02:07:19.714Z
# ...         ...           ...                       ...
# 2447       2147          1367  2024-02-02T02:06:58.408Z
# 2448       1439           617  2024-02-02T02:06:58.408Z
# 2449       2079          1298  2024-02-02T02:06:58.408Z
# 2450         -7            -7  2000-04-15T00:00:00.000Z
# 2451         -1            -1  1998-04-14T00:00:00.000Z
#
#       ROW_EXPIRATION_TIMESTAMP STORE_NAME STORE_TYPE_CODE STORE_TYPE_NAME  \
# 0     2024-05-21T02:07:19.714Z     NY2821            Fran       Franchise
# 1     2024-05-21T02:07:19.714Z     FL2822            Fran       Franchise
# ...

# %%
store['STORE_NUMBER'].nunique()
# Out:
# 2452

# %%
hierindex = pd.MultiIndex.from_tuples(list(zip(stores['STORE_KEY'].values,stores['STORE_NUMBER'].values,stores['OPEN_DATE'].values)))
stores.index=hierindex
stores.index.names=['STORE_KEY_INDEX','STORE_NUMBER_INDEX','OPEN_DATE']
stores=stores.sort_values('STORE_KEY_INDEX')

# %%
stores
# Out:
#                                                STORE_KEY  STORE_NUMBER  \
# STORE_KEY_INDEX STORE_NUMBER_INDEX OPEN_DATE
# -7              -7                 4/15/2000          -7            -7
# -1              -1                 4/14/1998          -1            -1
#  1               1691              6/26/2020           1          1691
#  2               1692              3/21/2020           2          1692
#  4               1694              12/21/2019          4          1694
# ...                                                  ...           ...
#  1319795         2821              12/31/1999    1319795          2821
#  1319796         2822              12/31/1999    1319796          2822
#  1319797         2817              12/31/1999    1319797          2817
#  1319798         2818              12/31/1999    1319798          2818
#  1319799         7050              12/31/1999    1319799          7050
#
# ...

# %%
pro = pd.read_csv('promotions.csv')

# %%
from datetime import datetime
format='%m/%d/%Y'
pro['PROMOTION_START_YEAR'] = pro['PROMOTION_START_DATE'].apply(lambda x: datetime.strptime(x,format).year)
pro[pro['PROMOTION_START_YEAR']==2022]
# Out:
#    PROMOTION_START_DATE PROMOTION_END_DATE    PROMOTION_TYPE PROMOTION_OFFER  \
# 2             3/17/2022          3/20/2022      Delivery Fee        Delivery
# 3             3/24/2022          3/27/2022      Delivery Fee        Delivery
# 4              4/1/2022           4/4/2022      Delivery Fee        Delivery
# 5             9/14/2022          9/22/2022      Delivery Fee        Delivery
# 6            10/31/2022         10/31/2022      Delivery Fee        Delivery
# 7             11/6/2022         11/10/2022         Free Item         Protein
# 8            11/10/2022         11/13/2022         Free Item            Side
# 9            11/15/2022          12/5/2022  Overall Discount             NaN
# 10           11/17/2022         11/20/2022         Free Item         Protein
# 11           11/22/2022          12/5/2022  Overall Discount             NaN
# 12           11/25/2022         11/27/2022         Free Item            Side
# ...

# %%
dfn[dfn['STORE_KEY']==694934]
# Out:
#                                                STORE_KEY  STORE_NUMBER  \
# STORE_KEY_INDEX STORE_NUMBER_INDEX OPEN_DATE
# 694934          2622               12/16/2023     694934          2622
#                                    12/16/2023     694934          2622
#                                    12/16/2023     694934          2622
#                                    12/16/2023     694934          2622
#                                    12/16/2023     694934          2622
#                                    12/16/2023     694934          2622
#                                    12/16/2023     694934          2622
#                                    12/16/2023     694934          2622
#                                    12/16/2023     694934          2622
#                                    12/16/2023     694934          2622
#                                    12/16/2023     694934          2622
#                                    12/16/2023     694934          2622
# ...

# %%
stores.head(10)
# Out:
#                                                STORE_KEY  STORE_NUMBER  \
# STORE_KEY_INDEX STORE_NUMBER_INDEX OPEN_DATE
# -7              -7                 4/15/2000          -7            -7
# -1              -1                 4/14/1998          -1            -1
#  1               1691              6/26/2020           1          1691
#  2               1692              3/21/2020           2          1692
#  4               1694              12/21/2019          4          1694
#  6               1696              12/28/2019          6          1696
#  7               1697              12/19/2019          7          1697
#  8               1698              3/5/2020            8          1698
#  10              1700              4/24/2020          10          1700
#  11              1701              3/6/2020           11          1701
#
#                                                 ROW_EFFECTIVE_TIMESTAMP  \
# STORE_KEY_INDEX STORE_NUMBER_INDEX OPEN_DATE
# ...

# %%
store.sort_values('STORE_KEY',inplace=True)
store.set_index('STORE_KEY',inplace=True)

# %%
store
# Out:
#            STORE_NUMBER   ROW_EFFECTIVE_TIMESTAMP  ROW_EXPIRATION_TIMESTAMP  \
# STORE_KEY
# -7                   -7  2000-04-15T00:00:00.000Z  2099-12-31T00:00:00.000Z
# -1                   -1  1998-04-14T00:00:00.000Z  2099-12-31T00:00:00.000Z
#  1                 1691  2024-05-23T02:07:01.674Z  2024-05-23T02:07:01.674Z
#  2                 1692  2024-02-02T02:06:58.408Z  2024-02-02T02:06:58.408Z
#  4                 1694  2024-03-26T02:06:59.305Z  2024-03-26T02:06:59.305Z
# ...                 ...                       ...                       ...
#  1319795           2821  2024-05-21T02:07:19.714Z  2024-05-21T02:07:19.714Z
#  1319796           2822  2024-05-21T02:07:19.714Z  2024-05-21T02:07:19.714Z
#  1319797           2817  2024-05-21T02:07:19.714Z  2024-05-21T02:07:19.714Z
#  1319798           2818  2024-05-21T02:07:19.714Z  2024-05-21T02:07:19.714Z
#  1319799           7050  2024-05-21T02:07:19.714Z  2024-05-21T02:07:19.714Z
#
# ...

# %%
store.drop(['COUNTRY_NAME','ROYALTY_RATE','PRIOR_STORE_NUMBER'],inplace=True,axis=1)

# %%
df2 = df['STORE_KEY']
df3 = pd.DataFrame(data=df2.unique(),columns=['STORE_KEY'])
df4 = pd.merge(df3,store,how='inner',on=['STORE_KEY'])
df4
# Out:
#      STORE_KEY  STORE_NUMBER   ROW_EFFECTIVE_TIMESTAMP  \
# 0         1402           580  2024-02-02T02:06:58.408Z
# 1         2104          1323  2024-05-14T02:06:44.743Z
# 2         1753           969  2024-01-30T02:06:54.251Z
# 3         2443          1664  2024-02-06T02:07:01.829Z
# 4         1859          1078  2024-02-02T02:06:58.408Z
# ..         ...           ...                       ...
# 414        702          2396  2024-02-06T02:07:01.829Z
# 415     491434          2584  2024-02-06T02:07:01.829Z
# 416        729          2423  2024-02-06T02:07:01.829Z
# 417     464545          2574  2024-01-31T02:06:50.749Z
# 418        769          2463  2024-02-06T02:07:01.829Z
#
#      ROW_EXPIRATION_TIMESTAMP STORE_NAME STORE_TYPE_CODE STORE_TYPE_NAME  \
# 0    2024-02-02T02:06:58.408Z      TN580            Fran       Franchise
# 1    2024-05-14T02:06:44.743Z     FL1323            Fran       Franchise
# 2    2024-01-30T02:06:54.251Z      TX969            Corp       Corporate
# ...

# %% [markdown]
# *Only 419 of the stores' data is available*

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df4.isnull())
# Out:
# <Axes: >

# %%
plt.figure(figsize=(6,30))
sns.countplot(df4,y='AREA_REGION',hue='STORE_CONCEPT_NAME')
# Out:
# <Axes: xlabel='count', ylabel='AREA_REGION'>

# %%
df4[df4['STORE_CONCEPT_NAME'].isnull()][['AREA_REGION','STORE_CONCEPT_NAME']]
# Out:
#                     AREA_REGION STORE_CONCEPT_NAME
# 164  SANTABARBRA-SANMAR-SANLUOB                NaN
# 356  SAN FRANCISCO-OAK-SAN JOSE                NaN
# 369                COLUMBUS, OH                NaN
# 370        HARTFORD & NEW HAVEN                NaN
# 387            DALLAS-FT. WORTH                NaN
# 394  SAN FRANCISCO-OAK-SAN JOSE                NaN
# 410                INDIANAPOLIS                NaN

# %%
result=pd.merge(df,df4,how='inner',on=['STORE_KEY','STORE_NUMBER','OPEN_DATE'])

# %%
merged=result.sort_values(['STORE_KEY','BUSINESS_DATE_KEY'])

# %%
def fill(row1,row2):
    if row1 != 0.0 and row1 != 1.0:
        if row2>0:
            row1=0.0
        else:
            row1=1.0
    return row1

# %%
merged['TEMP_CLOSE_INDICATOR']=merged.apply(lambda x: fill(x['TEMP_CLOSE_INDICATOR'],x['TRANSACTION_FINAL_COUNT']),axis=1)

# %%
hier_index = pd.MultiIndex.from_tuples(list(zip(merged['STORE_KEY'].values,merged['BUSINESS_DATE'].values)))
merged.index=hier_index
merged.index.names=['STORE_KEY_INDEX','BUSINESS_DATE']
merged
# Out:
#                                STORE_KEY  STORE_NUMBER   OPEN_DATE  \
# STORE_KEY_INDEX BUSINESS_DATE
# 10              4/24/2020             10          1700   4/24/2020
#                 4/25/2020             10          1700   4/24/2020
#                 4/26/2020             10          1700   4/24/2020
#                 4/27/2020             10          1700   4/24/2020
#                 4/28/2020             10          1700   4/24/2020
# ...                                  ...           ...         ...
# 491434          12/27/2023        491434          2584  12/16/2023
#                 12/28/2023        491434          2584  12/16/2023
#                 12/29/2023        491434          2584  12/16/2023
#                 12/30/2023        491434          2584  12/16/2023
#                 12/31/2023        491434          2584  12/16/2023
#
#                                BUSINESS_DATE_KEY BUSINESS_DATE  \
# STORE_KEY_INDEX BUSINESS_DATE
# ...

# %%
plt.figure(figsize=(20,50))
sns.heatmap(merged.isnull())
# Out:
# <Axes: ylabel='STORE_KEY_INDEX-BUSINESS_DATE'>

# %%
merged[['TEMP_CLOSE_INDICATOR','TRANSACTION_FINAL_COUNT']]
# Out:
#                                TEMP_CLOSE_INDICATOR  TRANSACTION_FINAL_COUNT
# STORE_KEY_INDEX BUSINESS_DATE
# 10              4/24/2020                       0.0                      168
#                 4/25/2020                       0.0                      184
#                 4/26/2020                       0.0                      158
#                 4/27/2020                       0.0                      125
#                 4/28/2020                       0.0                      110
# ...                                             ...                      ...
# 491434          12/27/2023                      0.0                      294
#                 12/28/2023                      0.0                      338
#                 12/29/2023                      0.0                      346
#                 12/30/2023                      0.0                      328
#                 12/31/2023                      0.0                      276
#
# ...

# %%
sns.heatmap(merged[['DISPATCH_GO_LIVE_DATE','DOOR_DASH_GO_LIVE_DATE','DOOR_DASH_MARKUP_GO_LIVE_DATE','STORE_CONCEPT_NAME','UBER_EATS_MARKUP_DATE']].isnull())
# Out:
# <Axes: ylabel='STORE_KEY_INDEX-BUSINESS_DATE'>

# %%
merged[['DISPATCH_GO_LIVE_DATE','DOOR_DASH_GO_LIVE_DATE','DOOR_DASH_MARKUP_GO_LIVE_DATE','STORE_CONCEPT_NAME','UBER_EATS_MARKUP_DATE']].head(30)
# Out:
#                               DISPATCH_GO_LIVE_DATE DOOR_DASH_GO_LIVE_DATE  \
# STORE_KEY_INDEX BUSINESS_DATE
# 10              4/24/2020                 4/24/2020              4/24/2020
#                 4/25/2020                 4/24/2020              4/24/2020
#                 4/26/2020                 4/24/2020              4/24/2020
#                 4/27/2020                 4/24/2020              4/24/2020
#                 4/28/2020                 4/24/2020              4/24/2020
#                 4/29/2020                 4/24/2020              4/24/2020
#                 4/30/2020                 4/24/2020              4/24/2020
#                 5/1/2020                  4/24/2020              4/24/2020
#                 5/2/2020                  4/24/2020              4/24/2020
#                 5/3/2020                  4/24/2020              4/24/2020
#                 5/4/2020                  4/24/2020              4/24/2020
# ...

# %%
merged['STORE_CONCEPT_NAME'].unique()
# Out:
# array(['Original', 'Ghost Kitchen', nan], dtype=object)

# %%
final = merged.drop('DOOR_DASH_GO_LIVE_DATE',axis=1)
final.dropna(inplace=True)

# %%
result_10 = merged[merged['STORE_KEY'] == 10]

# %%
format='%m/%d/%Y'
result_10['BUSINESS_DATE_DT'] = result_10['BUSINESS_DATE'].apply(lambda x: datetime.strptime(x,format))
result_10[result_10['BUSINESS_DATE']==2022]
store_10 = result_10.set_index('BUSINESS_DATE_DT')
store_10
# Out:
# C:\Users\chauh\AppData\Local\Temp\ipykernel_19856\521929012.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_10['BUSINESS_DATE_DT'] = result_10['BUSINESS_DATE'].apply(lambda x: datetime.strptime(x,format))
#                   STORE_KEY  STORE_NUMBER  OPEN_DATE  BUSINESS_DATE_KEY  \
# BUSINESS_DATE_DT
# 2020-04-24               10          1700  4/24/2020           20200424
# 2020-04-25               10          1700  4/24/2020           20200425
# 2020-04-26               10          1700  4/24/2020           20200426
# 2020-04-27               10          1700  4/24/2020           20200427
# 2020-04-28               10          1700  4/24/2020           20200428
# ...

# %%
plt.figure(figsize=(20,4))
sns.lineplot(x=result_10['BUSINESS_DATE'],y=result_10['NET_SALES_FINAL_USD_AMOUNT'])
plt.xticks([])
# Out:
# C:\Users\chauh\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\chauh\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ([], [])

# %% [markdown]
# *repeating patterns*

# %%
df2=df.drop(['OPEN_DATE','BUSINESS_DATE','STORE_NUMBER','PY_TRANSACTION_FINAL_COUNT','PY_NET_SALES_FINAL_USD_AMOUNT'],axis=1).set_index('STORE_KEY').corr().loc['NET_SALES_FINAL_USD_AMOUNT']

# %%
df2
# Out:
# BUSINESS_DATE_KEY                   0.192060
# TEMP_CLOSE_INDICATOR               -0.213624
# PROJECTION_INCLUDED_INDICATOR      -0.030062
# BUSINESS_DATE_FISCAL_DAY_OF_YEAR    0.015858
# BUSINESS_DATE_FISCAL_YEAR           0.192032
# COMP_BUSINESS_DATE_FISCAL_YEAR      0.192032
# COMPARABLE_INDICATOR                0.107547
# TRANSACTION_FINAL_COUNT             0.924908
# NET_SALES_FINAL_USD_AMOUNT          1.000000
# Name: NET_SALES_FINAL_USD_AMOUNT, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.barplot(y=df2.index,x=df2.values)
# Out:
# <Axes: >

# %% [markdown]
# # Preprocessing

# %%
sns.heatmap(final.isnull())
# Out:
# <Axes: ylabel='STORE_KEY_INDEX-BUSINESS_DATE'>

# %%
print(final[['ROW_EFFECTIVE_TIMESTAMP',
       'ROW_EXPIRATION_TIMESTAMP', 'STORE_NAME', 'STORE_TYPE_CODE',
       'STORE_TYPE_NAME', 'CLOSE_DATE', 'CITY_NAME', 'STATE_CODE',
       'STATE_NAME', 'COUNTRY_CODE', 'TIME_ZONE_NAME', 'DMA_ID', 'DMA_NAME',
       'STORE_STATUS', 'REGION_ID', 'REGION_NAME', 'STORE_LIVE_DATE',
       'STORE_FUNCTIONAL_STATUS', 'GLOBAL_REGION_NAME',
       'GLOBAL_REGION_STORE_TYPE_NAME', 'AREA_REGION']])
# Out:
#                                 ROW_EFFECTIVE_TIMESTAMP  \
# STORE_KEY_INDEX BUSINESS_DATE
# 10              4/24/2020      2024-05-22T02:07:18.404Z
#                 4/25/2020      2024-05-22T02:07:18.404Z
#                 4/26/2020      2024-05-22T02:07:18.404Z
#                 4/27/2020      2024-05-22T02:07:18.404Z
#                 4/28/2020      2024-05-22T02:07:18.404Z
# ...                                                 ...
# 491434          12/27/2023     2024-02-06T02:07:01.829Z
#                 12/28/2023     2024-02-06T02:07:01.829Z
#                 12/29/2023     2024-02-06T02:07:01.829Z
#                 12/30/2023     2024-02-06T02:07:01.829Z
#                 12/31/2023     2024-02-06T02:07:01.829Z
#
#                                ROW_EXPIRATION_TIMESTAMP STORE_NAME  \
# STORE_KEY_INDEX BUSINESS_DATE
# 10              4/24/2020      2024-05-22T02:07:18.404Z     CA1700
#                 4/25/2020      2024-05-22T02:07:18.404Z     CA1700
# ...

# %%
test = final.drop(['ROW_EFFECTIVE_TIMESTAMP','ROW_EXPIRATION_TIMESTAMP', 'STORE_NAME', 'STORE_TYPE_CODE',
       'STORE_TYPE_NAME','CITY_NAME', 'STATE_CODE','DMA_NAME','STORE_STATUS','REGION_NAME','TRANSACTION_FINAL_COUNT'
        'STATE_NAME', 'COUNTRY_CODE', 'TIME_ZONE_NAME','AREA_REGION','STORE_FUNCTIONAL_STATUS', 'GLOBAL_REGION_NAME','BUSINESS_DATE_FISCAL_DAY_OF_YEAR','EDW_CREATE_TIMESTAMP','EDW_MODIFY_TIMESTAMP'],axis=1)

# %%
format='%m/%d/%Y'
df=test.drop(['OPEN_DATE','BUSINESS_DATE','CLOSE_DATE','STORE_LIVE_DATE','DISPATCH_GO_LIVE_DATE','DOOR_DASH_MARKUP_GO_LIVE_DATE','UBER_EATS_MARKUP_DATE'],axis=1)
test = pd.concat([df,test[[c for c in test.columns if c.split('_')[-1] == 'DATE']].map(lambda x: datetime.strptime(x,format))],axis=1)

# %%
print(test['STORE_CONCEPT_NAME'].unique())
# Out:
# ['Original' 'Ghost Kitchen']

# %%
test = pd.concat([test,pd.get_dummies(test['GLOBAL_REGION_STORE_TYPE_NAME'],drop_first=True,dtype=float)],axis=1)
test = pd.concat([test,pd.get_dummies(test['STORE_CONCEPT_NAME'],drop_first=True,dtype=float)],axis=1)
test.drop(['GLOBAL_REGION_STORE_TYPE_NAME','STORE_CONCEPT_NAME'],axis=1,inplace=True)
test
# Out:
#                                STORE_KEY  STORE_NUMBER  BUSINESS_DATE_KEY  \
# STORE_KEY_INDEX BUSINESS_DATE
# 10              4/24/2020             10          1700           20200424
#                 4/25/2020             10          1700           20200425
#                 4/26/2020             10          1700           20200426
#                 4/27/2020             10          1700           20200427
#                 4/28/2020             10          1700           20200428
# ...                                  ...           ...                ...
# 491434          12/27/2023        491434          2584           20231227
#                 12/28/2023        491434          2584           20231228
#                 12/29/2023        491434          2584           20231229
#                 12/30/2023        491434          2584           20231230
#                 12/31/2023        491434          2584           20231231
#
# ...

# %%
for c in test.columns: 
    if c.split('_')[-1] == 'DATE':
        test[c+'_year'] = test[c].apply(lambda x: x.year)
        test[c+'_month'] = test[c].apply(lambda x: x.month)
        test[c+'_day'] = test[c].apply(lambda x: x.day)
        test.drop(c,inplace=True,axis=1)
test
# Out:
#                                STORE_KEY  STORE_NUMBER  BUSINESS_DATE_KEY  \
# STORE_KEY_INDEX BUSINESS_DATE
# 10              4/24/2020             10          1700           20200424
#                 4/25/2020             10          1700           20200425
#                 4/26/2020             10          1700           20200426
#                 4/27/2020             10          1700           20200427
#                 4/28/2020             10          1700           20200428
# ...                                  ...           ...                ...
# 491434          12/27/2023        491434          2584           20231227
#                 12/28/2023        491434          2584           20231228
#                 12/29/2023        491434          2584           20231229
#                 12/30/2023        491434          2584           20231230
#                 12/31/2023        491434          2584           20231231
#
# ...

# %% [markdown]
# # Training

# %%
for c in test.columns:
    pd.to_numeric(test[c])

# %%
test_train = pd.DataFrame(index=test.index,columns=test.columns)
test_test = pd.DataFrame(index=test.index,columns=test.columns)
for i in test['STORE_KEY'].unique():
    tempdf = test[test['STORE_KEY'] == i]
    test_test = pd.concat([test_test,tempdf[(tempdf['BUSINESS_DATE_year'] == 2023) & (tempdf['BUSINESS_DATE_month'] > 9)]],axis=0)
    test_train = pd.concat([test_train,tempdf[(tempdf['BUSINESS_DATE_year'] < 2023) | ((tempdf['BUSINESS_DATE_year'] == 2023) & (tempdf['BUSINESS_DATE_month'] <= 9))]],axis=0)
# Out:
# C:\Users\chauh\AppData\Local\Temp\ipykernel_19856\1358016866.py:5: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   test_test = pd.concat([test_test,tempdf[(tempdf['BUSINESS_DATE_year'] == 2023) & (tempdf['BUSINESS_DATE_month'] > 9)]],axis=0)
# C:\Users\chauh\AppData\Local\Temp\ipykernel_19856\1358016866.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
# ...

# %%
test_train.dropna(inplace=True)

# %%
test_test.dropna(inplace=True)

# %%
test_train.columns
# Out:
# Index(['STORE_KEY', 'STORE_NUMBER', 'BUSINESS_DATE_KEY',
#        'TEMP_CLOSE_INDICATOR', 'PROJECTION_INCLUDED_INDICATOR',
#        'BUSINESS_DATE_FISCAL_YEAR', 'COMP_BUSINESS_DATE_FISCAL_YEAR',
#        'COMPARABLE_INDICATOR', 'NET_SALES_FINAL_USD_AMOUNT',
#        'PY_TRANSACTION_FINAL_COUNT', 'PY_NET_SALES_FINAL_USD_AMOUNT', 'DMA_ID',
#        'REGION_ID', 'DomesticFranchise', 'Original', 'OPEN_DATE_year',
#        'OPEN_DATE_month', 'OPEN_DATE_day', 'BUSINESS_DATE_year',
#        'BUSINESS_DATE_month', 'BUSINESS_DATE_day', 'CLOSE_DATE_year',
#        'CLOSE_DATE_month', 'CLOSE_DATE_day', 'STORE_LIVE_DATE_year',
#        'STORE_LIVE_DATE_month', 'STORE_LIVE_DATE_day',
#        'DISPATCH_GO_LIVE_DATE_year', 'DISPATCH_GO_LIVE_DATE_month',
#        'DISPATCH_GO_LIVE_DATE_day', 'DOOR_DASH_MARKUP_GO_LIVE_DATE_year',
#        'DOOR_DASH_MARKUP_GO_LIVE_DATE_month',
#        'DOOR_DASH_MARKUP_GO_LIVE_DATE_day', 'UBER_EATS_MARKUP_DATE_year',
# ...

# %%
X_train = test_train.drop(['NET_SALES_FINAL_USD_AMOUNT'],axis=1)
y_train = test_train['NET_SALES_FINAL_USD_AMOUNT']
X_test = test_test.drop(['NET_SALES_FINAL_USD_AMOUNT'],axis=1)
y_test = test_test['NET_SALES_FINAL_USD_AMOUNT']

# %%
for c in X_train.columns:
    X_train[c]=pd.to_numeric(X_train[c])

y_train = pd.to_numeric(y_train)

for c in X_test.columns:
    X_test[c] = pd.to_numeric(X_test[c])

y_test = pd.to_numeric(y_test)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit_transform(X_train)
# Out:
# array([[0.        , 0.24260609, 0.2468956 , ..., 0.95454545, 0.54545455,
#         0.63333333],
#        [0.        , 0.24260609, 0.24692029, ..., 0.95454545, 0.54545455,
#         0.63333333],
#        [0.        , 0.24260609, 0.24694497, ..., 0.95454545, 0.54545455,
#         0.63333333],
#        ...,
#        [1.        , 0.24089156, 0.99995063, ..., 0.95454545, 0.54545455,
#         0.16666667],
#        [1.        , 0.24089156, 0.99997531, ..., 0.95454545, 0.54545455,
#         0.16666667],
#        [1.        , 0.24089156, 1.        , ..., 0.95454545, 0.54545455,
#         0.16666667]])

# %%
scaler.transform(X_test)
# Out:
# array([[  0.        ,   0.24260609,   1.00175278, ...,   0.95454545,
#           0.54545455,   0.63333333],
#        [  0.        ,   0.24260609,   1.00177747, ...,   0.95454545,
#           0.54545455,   0.63333333],
#        [  0.        ,   0.24260609,   1.00180216, ...,   0.95454545,
#           0.54545455,   0.63333333],
#        ...,
#        [200.00976801,   0.36890984,   1.00738144, ...,   1.        ,
#           1.        ,   0.5       ],
#        [200.00976801,   0.36890984,   1.00740613, ...,   1.        ,
#           1.        ,   0.5       ],
#        [200.00976801,   0.36890984,   1.00743081, ...,   1.        ,
#           1.        ,   0.5       ]])

# %%
import xgboost as xgb

# %%
reg = xgb.XGBRegressor(n_estimators=1000, early_stopping_rounds=50)
reg.fit(X_train,y_train,eval_set=[(X_train,y_train),(X_test,y_test)],verbose=True)
# Out:
# [0]	validation_0-rmse:1851.88187	validation_1-rmse:2367.28088
# [1]	validation_0-rmse:1600.36318	validation_1-rmse:2000.47448
# [2]	validation_0-rmse:1457.51256	validation_1-rmse:1767.82048
# [3]	validation_0-rmse:1368.61381	validation_1-rmse:1617.37601
# [4]	validation_0-rmse:1316.47868	validation_1-rmse:1500.34110
# [5]	validation_0-rmse:1288.57542	validation_1-rmse:1441.07703
# [6]	validation_0-rmse:1265.06791	validation_1-rmse:1411.66368
# [7]	validation_0-rmse:1247.28024	validation_1-rmse:1381.97104
# [8]	validation_0-rmse:1228.95224	validation_1-rmse:1354.49487
# [9]	validation_0-rmse:1218.33921	validation_1-rmse:1341.84802
# [10]	validation_0-rmse:1202.62823	validation_1-rmse:1329.27092
# [11]	validation_0-rmse:1195.60585	validation_1-rmse:1317.99775
# [12]	validation_0-rmse:1185.74360	validation_1-rmse:1312.08462
# [13]	validation_0-rmse:1173.52221	validation_1-rmse:1306.83928
# [14]	validation_0-rmse:1153.04807	validation_1-rmse:1297.79138
# ...

# %%
test_test['prediction'] = reg.predict(X_test)

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
print(test['STORE_KEY'].unique())
# Out:
# [    10     21     26     38     58     61     71     89    104    106
#     109    114    115    116    174    178    179    180    184    187
#     189    193    210    217    220    221    244    245    249    250
#     268    275    282    283    295    300    312    314    319    321
#     329    336    341    342    344    348    357    366    372    373
#     374    377    384    390    394    435    439    444    449    451
#     454    455    457    460    495    505    510    515    519    521
#     523    524    527    528    529    530    534    547    562    569
#     570    588    592    599    606    607    608    613    618    640
#     642    648    650    654    664    666    670    680    688    695
#     702    711    713    715    720    728    729    738    741    754
#     755    769    776    789    825    828    839    850    854    862
#     874    875    884    885    887    895    901    917    924    930
# ...

# %% [markdown]
# # 3-Month Predictions of Random Stores:-

# %% [markdown]
# ### 116

# %%
plt.figure(figsize=(20,4))
plt.xticks(rotation=90)
sns.lineplot(test_test.loc[116][['NET_SALES_FINAL_USD_AMOUNT','prediction']])
# Out:
# <Axes: xlabel='BUSINESS_DATE'>

# %% [markdown]
# ### 1005

# %%
plt.figure(figsize=(20,4))
plt.xticks(rotation=90)
sns.lineplot(test_test.loc[1005][['NET_SALES_FINAL_USD_AMOUNT','prediction']])
# Out:
# <Axes: xlabel='BUSINESS_DATE'>

# %% [markdown]
# ### 2289

# %%
plt.figure(figsize=(20,4))
plt.xticks(rotation=90)
sns.lineplot(test_test.loc[2289][['NET_SALES_FINAL_USD_AMOUNT','prediction']])
# Out:
# <Axes: xlabel='BUSINESS_DATE'>

# %% [markdown]
# ### 491434

# %%
plt.figure(figsize=(20,4))
plt.xticks(rotation=90)
sns.lineplot(test_test.loc[491434][['NET_SALES_FINAL_USD_AMOUNT','prediction']])
# Out:
# <Axes: xlabel='BUSINESS_DATE'>

# %%
test_test[['NET_SALES_FINAL_USD_AMOUNT','prediction']]
# Out:
#                                NET_SALES_FINAL_USD_AMOUNT   prediction
# STORE_KEY_INDEX BUSINESS_DATE
# 10              10/1/2023                         6365.53  6136.024902
#                 10/2/2023                         2774.74  4203.685059
#                 10/3/2023                         2913.84  3744.287109
#                 10/4/2023                         3377.74  3535.120605
#                 10/5/2023                         3669.20  3782.851318
# ...                                                   ...          ...
# 491434          12/27/2023                        6206.19  5907.816895
#                 12/28/2023                        7843.96  5907.816895
#                 12/29/2023                        7753.58  7380.462402
#                 12/30/2023                        8054.74  7546.757324
#                 12/31/2023                        7901.02  7490.731934
#
# [36727 rows x 2 columns]
